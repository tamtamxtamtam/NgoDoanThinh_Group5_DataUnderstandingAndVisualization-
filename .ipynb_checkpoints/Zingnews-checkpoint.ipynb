# %%
import pandas as pd
import math
import matplotlib.pyplot as plt     #I am pretty sure pyplot is the original functionality of matplotlib
import matplotlib.ticker as ticker
import numpy as np

# %%
df = pd.read_csv("outputzingnews.csv")

# %%
print(df)
# Out:
#                                                   link      Chủ đề  \
# 0    https://zingnews.vn/gojek-tung-video-chao-san-...    Đời sống
# 1    https://zingnews.vn/ve-dep-khu-do-thi-celadon-...  Kinh doanh
# 2    https://zingnews.vn/mazda3-turbo-2021-gia-re-h...          Xe
# 3    https://zingnews.vn/lam-gi-de-bao-ve-suc-khoe-...    Sức khỏe
# 4    https://zingnews.vn/anh-ve-tinh-cho-thay-50-be...    Thế giới
# ..                                                 ...         ...
# 121  https://zingnews.vn/chuyen-gia-cia-vu-no-o-bei...    Thế giới
# 122  https://zingnews.vn/fulham-co-co-hoi-doi-doi-s...    Thể thao
# 123  https://zingnews.vn/bo-y-te-yeu-cau-lam-ro-vu-...    Sức khỏe
# 124  https://zingnews.vn/tan-binh-chua-da-tran-nao-...    Thể thao
# 125  https://zingnews.vn/toyota-corolla-2020-ra-mat...          Xe
#
#                                                Tiêu đề  \
# 0    Gojek tung video chào sân hợp tác cùng đạo diễ...
# 1    Vẻ đẹp khu đô thị Celadon City qua góc máy của...
# 2      Mazda3 Turbo 2021 giá rẻ hơn Honda Civic Type R
# 3    Làm gì để bảo vệ sức khỏe khi dịch Covid-19 di...
# 4    Ảnh vệ tinh cho thấy 50% Beirut biến dạng sau ...
# ..                                                 ...
# 121  Chuyên gia CIA: Vụ nổ ở Beirut không chỉ do am...
# 122  Fulham có cơ hội đổi đời sau trận cầu đắt nhất...
# 123  Bộ Y tế yêu cầu làm rõ vụ người phụ nữ tử vong...
# 124  Tân binh chưa đá trận nào cho Barca sắp phải r...
# 125  Toyota Corolla 2020 ra mắt VN - chỉ nâng cấp n...
#
#                                                Tóm tắt  \
# 0    Kết hợp với Gojek trong chiến dịch ra mắt tại ...
# 1    Hệ sinh thái của Celadon City gồm công viên rộ...
# 2    Bốn phiên bản Mazda3 Turbo 2021 tại Mỹ có mức ...
# 3    Trong tình hình Covid-19 tại Việt Nam diễn tiế...
# 4    Ảnh vệ tinh chụp hôm 4/8 cho thấy vụ nổ tại cả...
# ..                                                 ...
# 121  Chuyên gia CIA cho rằng ammonium nitrate không...
# 122  Chiến thắng trước Brentford trong trận play-of...
# 123  Bộ Y tế yêu cầu xử lý tập thể, cá nhân sai phạ...
# 124  Đại diện xứ Catalonia đang cân nhắc bán tài nă...
# 125  Trái với những kỳ vọng ban đầu, thế hệ hoàn to...
#
#                                               Nội dung         Thời gian
# 0    Fan hâm mộ của các ngôi sao Mỹ như Dua Lipa, B...  20:00 05/08/2020
# 1    Là nhân vật chính của cuộc thi “Qua lăng kính ...  09:00 06/08/2020
# 2    Sau gần một tháng ra mắt, các model Mazda3 nân...  10:54 06/08/2020
# 3    Dịch Covid-19 bùng phát trở lại với ca ghi nhậ...  20:00 05/08/2020
# 4    Theo Guardian, ảnh vệ tinh chụp hôm 4/8 cho th...  18:41 05/08/2020
# ..                                                 ...               ...
# 121  Robert Baer, cựu điệp viên Cơ quan Tình báo Tr...  14:54 05/08/2020
# 122  Fulham giành chiến thắng 2-1 trước Brentford s...  14:58 05/08/2020
# 123  Ông Đinh Anh Tuấn, Phó vụ trưởng Vụ Sức khỏe B...  14:45 05/08/2020
# 124        Ngày 4/8, tin tức được phát đi từ nước A...  21:09 05/08/2020
# 125  Bên cạnh Corolla Cross, Toyota còn giới thiệu ...  20:20 05/08/2020
#
# [126 rows x 6 columns]

# %%
print(df.keys())
# Out:
# Index(['link', 'Chủ đề', 'Tiêu đề', 'Tóm tắt', 'Nội dung', 'Thời gian'], dtype='object')

# %%
print(df['Thời gian'])
# Out:
# 0      20:00 05/08/2020
# 1      09:00 06/08/2020
# 2      10:54 06/08/2020
# 3      20:00 05/08/2020
# 4      18:41 05/08/2020
#              ...
# 121    14:54 05/08/2020
# 122    14:58 05/08/2020
# 123    14:45 05/08/2020
# 124    21:09 05/08/2020
# 125    20:20 05/08/2020
# Name: Thời gian, Length: 126, dtype: object

# %%
title = df['Chủ đề']
link = df['link']

# %%
plt.bar(title, link)
plt.show()
